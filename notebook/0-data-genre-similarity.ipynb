# %% [markdown]
# # Playlist Group Based on Genre Similarity

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

pd.set_option('display.max_rows', None)

# %%
# Read in the data
data = pd.read_csv('../data/ph_spotify_daily_charts_artists1.csv')

# Filter out rows with empty genres
data = data[data['genres'] != '[]']
data.head()
# Out:
#                 artist_id       artist_name  total_followers  \
# 0  0du5cEVh5yTK9QJze8zA0C        Bruno Mars         47387027
# 1  4IWBUUAFIplrNtaOHcJPRM      James Arthur         11471232
# 2  69GGBxA162lTqCwzJG5jLp  The Chainsmokers         20036566
# 3  04gDigrS5kc9YWfZHwBETP          Maroon 5         40125006
# 4  5p7f24Rk5HkUZsaS3BLG5F  Hailee Steinfeld          8535540
#
#                                               genres  popularity
# 0                               ['dance pop', 'pop']          89
# 1                   ['pop', 'talent show', 'uk pop']          82
# 2  ['dance pop', 'edm', 'electropop', 'pop', 'pop...          81
# 3                                            ['pop']          86
# 4              ['dance pop', 'pop', 'post-teen pop']          73

# %%
# Filter for artists with genres
data = data[data['genres'].notnull()]

# %%
# Convert genre strings to lists
data['genres'] = data['genres'].apply(lambda x: x.strip('[]').split(', '))

# %%
# Remove duplicates and reset index
data = data.drop_duplicates(subset=['artist_id']).reset_index(drop=True)

# %%
# Filter for Dilaw songs
dilaw = data[data['artist_name'] == 'Dilaw']

# %%
# Create CountVectorizer object and fit_transform on genres
cv = CountVectorizer(tokenizer=lambda x: x, lowercase=False)
genres_cv = cv.fit_transform(data['genres'].apply(lambda x: ' '.join(x)))
# Out:
# d:\Justin\Documents\Learn\Eskwelabs-DS\sprint-3\venv-eskwelabs-ds-s3\lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
# Compute cosine similarity matrix
cos_sim = cosine_similarity(genres_cv)

# %%
# Get index of Dilaw songs in the data
dilaw_index = dilaw.index[0]

# %%
# Compute cosine similarity scores of all songs to Dilaw songs
dilaw_scores = cos_sim[dilaw_index]

# %%
# Get indices of songs with highest cosine similarity scores
most_similar_indices = dilaw_scores.argsort()[:-100:-1]
most_similar_genres = data.iloc[most_similar_indices][['artist_name', 'genres', 'popularity']]
most_similar_genres = most_similar_genres.explode('genres')
most_similar_genres = most_similar_genres.groupby('genres').agg({'artist_name': ', '.join, 'popularity': 'mean'}).reset_index()
most_similar_genres.rename(columns={'artist_name': 'artists'}, inplace=True)

# Create a new dataframe with cosine distances
similar_cosine_distances = pd.DataFrame({'cosine_distance': 1 - dilaw_scores[most_similar_indices]})

# Concatenate the two dataframes
most_similar_genres = pd.concat([most_similar_genres, similar_cosine_distances], axis=1)

# %%
# Display the most similar genres
print('Most Similar Genres:')
most_similar_genres.head(50)
# Out:
# Most Similar Genres:
#                           genres  \
# 0               'acoustic cover'
# 1                 'afrofuturism'
# 2                        'alt z'
# 3          'alternative hip hop'
# 4            'alternative metal'
# 5         'alternative pop rock'
# 6              'alternative r&b'
# 7             'alternative rock'
# 8            'argentine hip hop'
# 9                      'art pop'
# 10                    'art rock'
# 11                 'atl hip hop'
# 12               'aussietronica'
# 13            'australian dance'
# 14       'australian electropop'
# 15            'australian indie'
# 16              'australian pop'
# 17                 'baroque pop'
# 18                   'bass trap'
# 19                  'beatlesque'
# 20                 'bedroom pop'
# 21               'belgian dance'
# 22                 'belgian edm'
# 23                    'big room'
# 24                  'bisaya rap'
# 25                'british soul'
# 26                     'britpop'
# 27              'brooklyn indie'
# 28                'bubblegrunge'
# 29                'canadian ccm'
# 30         'canadian electronic'
# 31           'canadian pop punk'
# 32                         'ccm'
# 33                   'cdo indie'
# 34               'chicago indie'
# 35  'christian alternative rock'
# 36             'christian music'
# 37              'christian punk'
# 38                'classic rock'
# 39                  'complextro'
# 40            'contemporary r&b'
# 41                'covertronica'
# 42                   'dance pop'
# 43                  'dance rock'
# 44           'danish electronic'
# 45                  'danish pop'
# 46                    'dark pop'
# 47         'deep tropical house'
# 48                   'downtempo'
# 49            'eau claire indie'
#
#                                               artists  popularity  \
# 0                                        Boyce Avenue   71.000000
# 1                                       Janelle Monáe   67.000000
# 2   VÉRITÉ, Chelsea Cutler, Carlie Hanson, Claire ...   58.857143
# 3                                  Dilaw, Oliver Tree   72.000000
# 4                                           Lifehouse   65.000000
# 5                                        Dominic Fike   74.000000
# 6                                       Janelle Monáe   67.000000
# 7                                               Dilaw   64.000000
# 8                                            Bizarrap   88.000000
# 9           Kate Bush, King Princess, Hayley Williams   66.000000
# 10                                          Kate Bush   72.000000
# 11                               Janelle Monáe, Usher   73.500000
# 12                                            Starley   56.000000
# 13                               Flume, Kylie Minogue   71.000000
# 14                                              Flume   73.000000
# 15                                              Flume   73.000000
# 16                                      Kylie Minogue   69.000000
# 17                                          Kate Bush   72.000000
# 18                                        Yellow Claw   64.000000
# 19                                              Oasis   77.000000
# 20                                        girl in red   76.000000
# 21                          Dimitri Vegas & Like Mike   71.000000
# 22                          Dimitri Vegas & Like Mike   71.000000
# 23                          Dimitri Vegas & Like Mike   71.000000
# 24                                          Soulthrll   46.000000
# 25                                       Paloma Faith   70.000000
# 26                                              Oasis   77.000000
# 27                                             VÉRITÉ   52.000000
# 28                                        Beach Bunny   69.000000
# 29                                          FM Static   53.000000
# 30                                              DVBBS   65.000000
# 31                                          FM Static   53.000000
# 32                                    Hillsong UNITED   72.000000
# 33                             TJ Monterde, Soulthrll   53.500000
# 34                                        Beach Bunny   69.000000
# 35                         FM Static, Hillsong UNITED   62.500000
# 36                                    Hillsong UNITED   72.000000
# 37                                          FM Static   53.000000
# 38                                  Bruce Springsteen   76.000000
# 39                                               Zedd   76.000000
# 40                                              Usher   80.000000
# 41                      ACRAZE, Dynoro, Topic, Regard   70.750000
# 42  ACRAZE, Dimitri Vegas & Like Mike, Dynoro, MØ,...   69.739130
# 43                                      WALK THE MOON   70.000000
# 44                           Martin Jensen, HEDEGAARD   63.000000
# 45                                                 MØ   71.000000
# 46                                             VÉRITÉ   52.000000
# 47                                      A R I Z O N A   61.000000
# 48                                              Flume   73.000000
# 49                                    Big Red Machine   56.000000
#
#     cosine_distance
# 0          0.000000
# 1          0.047543
# 2          0.055189
# 3          0.061045
# 4          0.072770
# 5          0.074737
# 6          0.079651
# 7          0.081944
# 8          0.083562
# 9          0.084167
# 10         0.084300
# 11         0.084652
# 12         0.085504
# 13         0.086236
# 14         0.087927
# 15         0.088465
# 16         0.088751
# 17         0.089117
# 18         0.089230
# 19         0.089303
# 20         0.090475
# 21         0.090722
# 22         0.090816
# 23         0.091125
# 24         0.091909
# 25         0.091909
# 26         0.093528
# 27         0.093963
# 28         0.094578
# 29         0.094578
# 30         0.094822
# 31         0.095296
# 32         0.095636
# 33         0.096381
# 34         0.097300
# 35         0.097374
# 36         0.097378
# 37         0.097444
# 38         0.097483
# 39         0.097591
# 40         0.097652
# 41         0.097741
# 42         0.098658
# 43         0.099573
# 44         0.100983
# 45         0.101290
# 46         0.101373
# 47         0.102006
# 48         0.102423
# 49         0.102444

# %%
# Get indices of songs with lowest cosine similarity scores
least_similar_indices = dilaw_scores.argsort()[:200]
least_similar_genres = data.iloc[least_similar_indices][['artist_name', 'genres', 'popularity']]
least_similar_genres = least_similar_genres.explode('genres')
least_similar_genres = least_similar_genres.groupby('genres').agg({'artist_name': ', '.join, 'popularity': 'mean'}).reset_index()
least_similar_genres.rename(columns={'artist_name': 'artists'}, inplace=True)

# Create a new dataframe with cosine distances
distant_cosine_distances = pd.DataFrame({'cosine_distance': 1 - dilaw_scores[least_similar_indices]})

# Concatenate the two dataframes
least_similar_genres = pd.concat([least_similar_genres, distant_cosine_distances], axis=1)

# %%
# Display the least similar genres
print('Least Similar Genres:')
least_similar_genres.head(50)
# Out:
# Least Similar Genres:
#                 genres                                            artists  \
# 0         'a cappella'                                         Pentatonix
# 1    'adult standards'           Darlene Love, Nat King Cole, Bobby Helms
# 2           'afro r&b'                                               CKay
# 3       'afrofuturism'                                         Steve Lacy
# 4              'alt z'                                          Rosa Linn
# 5          'bass trap'                                         Zookeepers
# 6           'basshall'                                       Aya Nakamura
# 7        'bedroom pop'                                       d4vd, A-Wall
# 8     'brooklyn drill'                                          Pop Smoke
# 9      'bubblegum pop'                                  Edison Lighthouse
# 10         'chill r&b'                        grentperez, Larissa Lambert
# 11         'dutch edm'                                       Leroy Styles
# 12       'dutch house'                               Kris Kross Amsterdam
# 13         'dutch pop'              Duncan Laurence, Kris Kross Amsterdam
# 14               'edm'                                          Silk City
# 15        'electropop'                                        Marian Hill
# 16         'eurodance'                                             Nevada
# 17           'europop'                                 Daniel Bedingfield
# 18          'folk-pop'                                            Seafret
# 19         'high vibe'                                          Emmy Meli
# 20         'hollywood'  Evan Rachel Wood, Michelle Williams, Anna Kend...
# 21          'jawaiian'                                           Conkarah
# 22   'k-pop boy group'  EXO-SC, BIGBANG, NCT 127, TOMORROW X TOGETHER,...
# 23  'k-pop girl group'  NMIXX, IVE, aespa, K/DA, ITZY, IZ*ONE, MOMOLAN...
# 24             'k-pop'  KAI, JIN, Jung Kook, X1, TAEYONG, JENNIE, Jess...
# 25             'k-rap'    True Damage, RM, Agust D, Balming Tiger, j-hope
# 26            'la pop'                                               LANY
# 27  'musical advocacy'                                           Band Aid
# 28           'nyc pop'                                              Dawin
# 29            'nz pop'                                          Jawsh 685
# 30               'opm'  Jay R, Inigo Pascual, Kithara, Morissette, NOB...
# 31             'p-pop'  Magnus Haven, John Roa, This Band, Music Hero,...
# 32           'pop r&b'                     Poo Bear, Justine Skye, Khalid
# 33           'pop rap'                        Y2K, Jon Bellion, blackbear
# 34          'pop rock'                                                AJR
# 35          'pop soul'                                       Jamie Miller
# 36               'pop'  Noah Cyrus, RealestK, Adie, Taylor Swift, Oliv...
# 37               'r&b'          Kaash Paige, SZA, Giveon, Michael Jackson
# 38               'rap'                                       Metro Boomin
# 39     'rock-and-roll'                                      Elvis Presley
# 40        'rockabilly'                                      Elvis Presley
# 41         'sad lo-fi'                                               Kina
# 42           'sad rap'                               347aidan, BoyWithUke
# 43        'show tunes'  Ziv Zaifman, Emma Thompson, Austyn Johnson, St...
# 44       'smooth jazz'                             Grover Washington, Jr.
# 45              'soul'                                    Michael Jackson
# 46           'sped up'                    Music Factory, Trinidad Cardona
# 47       'swedish pop'                                     Joakim Lundell
# 48       'tagalog rap'                                        Jeff Grecia
# 49            'uk pop'               Sam Smith, Ed Sheeran, Lewis Capaldi
#
#     popularity  cosine_distance
# 0    65.000000         0.609428
# 1    54.666667         0.557899
# 2    72.000000         0.532047
# 3    83.000000         0.532047
# 4    75.000000         0.532047
# 5    44.000000         0.532047
# 6    74.000000         0.532047
# 7    70.500000         0.532047
# 8    84.000000         0.521648
# 9    59.000000         0.485683
# 10   59.000000         0.485683
# 11   30.000000         0.485683
# 12   64.000000         0.485683
# 13   66.500000         0.485683
# 14   56.000000         0.485683
# 15   55.000000         0.485683
# 16   47.000000         0.485683
# 17   54.000000         0.485683
# 18   73.000000         0.485683
# 19   56.000000         0.485683
# 20   60.181818         0.485683
# 21   52.000000         0.485683
# 22   69.785714         0.485683
# 23   66.705882         0.485683
# 24   64.785714         0.485683
# 25   65.400000         0.485683
# 26   74.000000         0.485683
# 27   43.000000         0.485683
# 28   51.000000         0.485683
# 29   63.000000         0.485683
# 30   49.113208         0.485683
# 31   54.000000         0.485683
# 32   72.000000         0.485683
# 33   70.000000         0.485683
# 34   75.000000         0.485683
# 35   66.000000         0.485683
# 36   78.481481         0.485683
# 37   81.250000         0.480462
# 38   90.000000         0.465795
# 39   80.000000         0.463893
# 40   80.000000         0.463893
# 41   69.000000         0.463893
# 42   72.500000         0.463893
# 43   59.250000         0.463893
# 44   64.000000         0.463893
# 45   83.000000         0.463893
# 46   63.500000         0.463893
# 47   47.000000         0.463893
# 48   61.000000         0.463893
# 49   87.666667         0.463893
